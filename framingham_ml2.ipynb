# %%
#Import dependencies
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from imblearn.combine import SMOTEENN
import sqlalchemy as sa
from sqlalchemy import create_engine
import psycopg2 as pg
from sklearn.metrics import classification_report
import tensorflow as tf
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.svm import SVC

# %% [markdown]
# # Preliminary data preprocessing
# For the data preprocessing the data was imported from the database in *AWS* and connected to *postgresq*l using *sqlalchemy*. The data was checked for duplicate and null values. The null valued were dropped and there were no duplicate entries. The column 'male' was changed to 'sex' for clarity. This part of the preprocessing was done when the data was imported to the database.

# %%
#Connect to Postgresql database 
conn=sa.create_engine('postgresql://root:postgres@dataanalyticsdb.cxnhjzyey4ka.us-east-2.rds.amazonaws.com:5432/coursefinalproject')

# %%
#Load and display data
df=pd.read_sql_query("SELECT * FROM fragmingham", con=conn)
df
# Out:
#       sex  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0       1   39        4.0              0         0.0     0.0                0
# 1       0   46        2.0              0         0.0     0.0                0
# 2       1   48        1.0              1        20.0     0.0                0
# 3       0   61        3.0              1        30.0     0.0                0
# 4       0   46        3.0              1        23.0     0.0                0
# ...   ...  ...        ...            ...         ...     ...              ...
# 3653    1   50        1.0              1         1.0     0.0                0
# 3654    1   51        3.0              1        43.0     0.0                0
# 3655    0   52        2.0              0         0.0     0.0                0
# 3656    1   40        3.0              0         0.0     0.0                0
# 3657    0   39        3.0              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 3653             1         0    313.0  179.0   92.0  25.97       66.0
# 3654             0         0    207.0  126.5   80.0  19.71       65.0
# 3655             0         0    269.0  133.5   83.0  21.47       80.0
# 3656             1         0    185.0  141.0   98.0  25.60       67.0
# 3657             0         0    196.0  133.0   86.0  20.91       85.0
#
#       glucose  TenYearCHD
# 0        77.0           0
# 1        76.0           0
# 2        70.0           0
# 3       103.0           1
# 4        85.0           0
# ...       ...         ...
# 3653     86.0           1
# 3654     68.0           0
# 3655    107.0           0
# 3656     72.0           0
# 3657     80.0           0
#
# [3658 rows x 16 columns]

# %%
#Diplay column names
df.columns
# Out:
# Index(['sex', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
#Explore data types
df.dtypes
# Out:
# sex                  int64
# age                  int64
# education          float64
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
#Explore for null value
df.isnull().sum()
# Out:
# sex                0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
#Find duplicates
print(f'Duplicate entries:{df.duplicated().sum()}')
# Out:
# Duplicate entries:0

# %% [markdown]
# - The dataset contains two similar features, one of them is if the participant smokes *currentSmoker* and number of cigarettes per day *cigsPerDay* that the person smokes. *currenSmoker* is categorical (0=non-smoker or 1=smoker) and *cigsPerDay* is continuous (float64). If *currentSmoker* is 0, then *cigsPerDay* would be 0. These two features showed high correlation in the exploratory data analysis  so *currentSmoker* was dropped in favour of *cigsPerDay*.
# - After running the *Balanced Random Forest Classifier* for the first time and checking the *importances* we decided to drop some additional columns as their value did not even reach 0.01.

# %%
#Drop unncessary columns and display DataFrame
df.drop(columns=['currentSmoker', 'prevalentStroke','BPMeds','diabetes' ], inplace=True)
df
# Out:
#       sex  age  education  cigsPerDay  prevalentHyp  totChol  sysBP  diaBP  \
# 0       1   39        4.0         0.0             0    195.0  106.0   70.0
# 1       0   46        2.0         0.0             0    250.0  121.0   81.0
# 2       1   48        1.0        20.0             0    245.0  127.5   80.0
# 3       0   61        3.0        30.0             1    225.0  150.0   95.0
# 4       0   46        3.0        23.0             0    285.0  130.0   84.0
# ...   ...  ...        ...         ...           ...      ...    ...    ...
# 3653    1   50        1.0         1.0             1    313.0  179.0   92.0
# 3654    1   51        3.0        43.0             0    207.0  126.5   80.0
# 3655    0   52        2.0         0.0             0    269.0  133.5   83.0
# 3656    1   40        3.0         0.0             1    185.0  141.0   98.0
# 3657    0   39        3.0        30.0             0    196.0  133.0   86.0
#
#         BMI  heartRate  glucose  TenYearCHD
# 0     26.97       80.0     77.0           0
# 1     28.73       95.0     76.0           0
# 2     25.34       75.0     70.0           0
# 3     28.58       65.0    103.0           1
# 4     23.10       85.0     85.0           0
# ...     ...        ...      ...         ...
# 3653  25.97       66.0     86.0           1
# 3654  19.71       65.0     68.0           0
# 3655  21.47       80.0    107.0           0
# 3656  25.60       67.0     72.0           0
# 3657  20.91       85.0     80.0           0
#
# [3658 rows x 12 columns]

# %%
#Display basic statistical info
df.describe()
# Out:
#                sex          age    education   cigsPerDay  prevalentHyp  \
# count  3658.000000  3658.000000  3658.000000  3658.000000   3658.000000
# mean      0.443685    49.551941     1.980317     9.025424      0.311646
# std       0.496886     8.562029     1.022656    11.921590      0.463229
# min       0.000000    32.000000     1.000000     0.000000      0.000000
# 25%       0.000000    42.000000     1.000000     0.000000      0.000000
# 50%       0.000000    49.000000     2.000000     0.000000      0.000000
# 75%       1.000000    56.000000     3.000000    20.000000      1.000000
# max       1.000000    70.000000     4.000000    70.000000      1.000000
#
#            totChol        sysBP        diaBP          BMI    heartRate  \
# count  3658.000000  3658.000000  3658.000000  3658.000000  3658.000000
# mean    236.847731   132.370558    82.917031    25.782802    75.730727
# std      44.097681    22.086866    11.974258     4.065601    11.981525
# min     113.000000    83.500000    48.000000    15.540000    44.000000
# 25%     206.000000   117.000000    75.000000    23.080000    68.000000
# 50%     234.000000   128.000000    82.000000    25.380000    75.000000
# 75%     263.000000   143.875000    90.000000    28.037500    82.000000
# max     600.000000   295.000000   142.500000    56.800000   143.000000
#
#            glucose   TenYearCHD
# count  3658.000000  3658.000000
# mean     81.852925     0.152269
# std      23.904164     0.359331
# min      40.000000     0.000000
# 25%      71.000000     0.000000
# 50%      78.000000     0.000000
# 75%      87.000000     0.000000
# max     394.000000     1.000000

# %%
#Locate outliers for totChol
df.loc[df.totChol>500]
# Out:
#      sex  age  education  cigsPerDay  prevalentHyp  totChol  sysBP  diaBP  \
# 966    0   52        2.0         0.0             1    600.0  159.5   94.0
#
#        BMI  heartRate  glucose  TenYearCHD
# 966  28.27       78.0    140.0           1

# %% [markdown]
# - The extreme outlier of 600 for *totChol* was dropped.

# %%
#Drop extreme values for totChol
df=df.drop(df[df['totChol']>500].index)
df.reset_index(drop=True)
# Out:
#       sex  age  education  cigsPerDay  prevalentHyp  totChol  sysBP  diaBP  \
# 0       1   39        4.0         0.0             0    195.0  106.0   70.0
# 1       0   46        2.0         0.0             0    250.0  121.0   81.0
# 2       1   48        1.0        20.0             0    245.0  127.5   80.0
# 3       0   61        3.0        30.0             1    225.0  150.0   95.0
# 4       0   46        3.0        23.0             0    285.0  130.0   84.0
# ...   ...  ...        ...         ...           ...      ...    ...    ...
# 3652    1   50        1.0         1.0             1    313.0  179.0   92.0
# 3653    1   51        3.0        43.0             0    207.0  126.5   80.0
# 3654    0   52        2.0         0.0             0    269.0  133.5   83.0
# 3655    1   40        3.0         0.0             1    185.0  141.0   98.0
# 3656    0   39        3.0        30.0             0    196.0  133.0   86.0
#
#         BMI  heartRate  glucose  TenYearCHD
# 0     26.97       80.0     77.0           0
# 1     28.73       95.0     76.0           0
# 2     25.34       75.0     70.0           0
# 3     28.58       65.0    103.0           1
# 4     23.10       85.0     85.0           0
# ...     ...        ...      ...         ...
# 3652  25.97       66.0     86.0           1
# 3653  19.71       65.0     68.0           0
# 3654  21.47       80.0    107.0           0
# 3655  25.60       67.0     72.0           0
# 3656  20.91       85.0     80.0           0
#
# [3657 rows x 12 columns]

# %% [markdown]
# # Create features and split data into training and testing
# - Our target is *TenYearCHD* which is the result of the Framingham risk score that determines whether a person is at risk of developing coronary heart disease in 10 years. The values of the target are categorical as int64 (0=is not at risk of developing CHD in ten years/1=at risk of developing CHD in ten years).
# - The rest of the features are: *sex, age, education, cigsPerDay, prevalentHyp, totChol, sysBP, diaBP, BMI, heartRate and glucose*.

# %%
#Create features
X=df.copy()
X=X.drop(columns='TenYearCHD')

#Create target
y=df[['TenYearCHD']]

y.shape
# Out:
# (3657, 1)

# %%
#Check balance of target values
y['TenYearCHD'].value_counts()
# Out:
# 0    3101
# 1     556
# Name: TenYearCHD, dtype: int64

# %% [markdown]
# # How data was split into training and testing sets
# The data was split into training and testing sets using the *scikitlearn* module `test_train_split()`. Given the imbalance in the dataset in the target class (*TenYearCHD*) the data was stratified (`stratify=y`) during the split.

# %%
#Split data into Train and Test Sets
X_train, X_test, y_train, y_test=train_test_split(X,y, random_state=1, stratify=y)
print(f'Xtrain:{X_train.shape}')
print(f'y_train:{y_train.shape}')
print(f'X_test:{X_test.shape}')
print(f'y_test:{y_test.shape}')
# Out:
# Xtrain:(2742, 11)
# y_train:(2742, 1)
# X_test:(915, 11)
# y_test:(915, 1)

# %% [markdown]
# # Scale the  data
# Given the difference in values and that some features are continuous and some are categorical the data was standardized using *scikitlearn* `StandardScaler`.

# %%
#Create a StandardScaler instance
scaler=StandardScaler()

#Fit StandardScaler()
X_scaler=scaler.fit(X_train)

#Scaling data
X_train_scaled=X_scaler.transform(X_train)

X_test_scaled=X_scaler.transform(X_test)

# %% [markdown]
# # First model choice
# The first Machine Learning model we chose is *Logistic Regression* as we are trying to predict a discrete binary outcome. *Logistic regression* is easier to implement, interpret, and very efficient to train. It can have good accuracy for many simple data sets and it performs well when the dataset is linearly separable. Although we believe *Logistic regression* might work in this case, logistic regression inherently runs on a linear model and there are other models available which could also prove useful.

# %% [markdown]
# ##  Resample with  Random oversampling
# Given that the dataset is imbalanced we resampled the data using *RandomOverSampler* from the *imblearn* library.

# %%
# Implement random oversampling
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train_scaled, y_train)

# %%
print(X_resampled.shape)
print(y_resampled.shape)
# Out:
# (4650, 11)
# (4650, 1)

# %%
#Perform Logistic Regression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
#Make Predictions
y_pred = model.predict(X_test_scaled)

# %%
#Display confusion maxtrix as a DataFrame
cm=confusion_matrix(y_test, y_pred)
cm_df=pd.DataFrame(cm, index=['Actual 0','Actual 1'], columns=['Predicted 0', 'Predicted 1'])
cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0          499          277
# Actual 1           42           97

# %%
#Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.64      0.76       776
#            1       0.26      0.70      0.38       139
#
#     accuracy                           0.65       915
#    macro avg       0.59      0.67      0.57       915
# weighted avg       0.82      0.65      0.70       915

# %% [markdown]
# # Additional Models for comparisson

# %% [markdown]
# ## SMOTEENN and Logistic Regression

# %%
#Resample the training data SMOTEENN
smote_enn=SMOTEENN(random_state=1)
X_resampled, y_resampled=smote_enn.fit_resample(X_train_scaled,y_train)

# %%
print(X_resampled.shape)
print(y_resampled.shape)
# Out:
# (3489, 11)
# (3489, 1)

# %%
#Train the model
model=LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
#Make Predictions
y_pred = model.predict(X_test_scaled)
confusion_matrix(y_test, y_pred)
# Out:
# array([[362, 414],
#        [ 22, 117]], dtype=int64)

# %%
#Display confusion maxtrix as a DataFrame
cm=confusion_matrix(y_test, y_pred)
cm_df=pd.DataFrame(cm, index=['Actual 0','Actual 1'], columns=['Predicted 0', 'Predicted 1'])
cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0          362          414
# Actual 1           22          117

# %%
#Print the classification report
print (classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.47      0.62       776
#            1       0.22      0.84      0.35       139
#
#     accuracy                           0.52       915
#    macro avg       0.58      0.65      0.49       915
# weighted avg       0.83      0.52      0.58       915

# %% [markdown]
# ##   Balanced Random Forest Classifier

# %%
#Train the Balanced Random Forest Classifier
brf=BalancedRandomForestClassifier(n_estimators=100, random_state=1)
brf.fit(X_train_scaled, y_train)
# Out:
# BalancedRandomForestClassifier(random_state=1)

# %%
#Make predictions
y_pred=brf.predict(X_test_scaled)

# %%
#Display the confusion matrix
cm=confusion_matrix(y_test, y_pred)
cm_df=pd.DataFrame(cm, index=['Actual 0','Actual 1'], columns=['Predicted 0', 'Predicted 1'])
cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0          488          288
# Actual 1           44           95

# %%
#Print the  classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.63      0.75       776
#            1       0.25      0.68      0.36       139
#
#     accuracy                           0.64       915
#    macro avg       0.58      0.66      0.56       915
# weighted avg       0.82      0.64      0.69       915

# %%
#List the features sorted in descending order by feature importance
importances=brf.feature_importances_
sorted(zip(brf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.16351460455779293, 'age'),
#  (0.1405446659512617, 'sysBP'),
#  (0.11945616965365684, 'BMI'),
#  (0.11898302288134119, 'totChol'),
#  (0.11379731879715406, 'diaBP'),
#  (0.11193782917345585, 'glucose'),
#  (0.09090217881065187, 'heartRate'),
#  (0.05585240785767976, 'cigsPerDay'),
#  (0.03781316162465326, 'education'),
#  (0.02605843137640234, 'sex'),
#  (0.02114020931595029, 'prevalentHyp')]

# %% [markdown]
# ##  Neural Network

# %%
#Define the basic neural network model
number_input_features=len(X_train_scaled[0])

nn_model=tf.keras.models.Sequential()

#First hidden layer
nn_model.add(tf.keras.layers.Dense(units=80, input_dim=number_input_features, activation='relu'))

#Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation='relu'))

#Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation='relu'))

#Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

#Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                960
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 30)                930
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 4,351
# Trainable params: 4,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile the model
nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#Train the model
nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 86/86 [==============================] - 5s 3ms/step - loss: 0.4732 - accuracy: 0.8104
# Epoch 2/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8483
# Epoch 3/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8523
# Epoch 4/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.8549
# Epoch 5/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3699 - accuracy: 0.8530
# Epoch 6/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3638 - accuracy: 0.8563
# Epoch 7/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3644 - accuracy: 0.8549
# Epoch 8/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3588 - accuracy: 0.8549
# Epoch 9/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3553 - accuracy: 0.8556
# Epoch 10/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3536 - accuracy: 0.8545
# Epoch 11/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3510 - accuracy: 0.8592
# Epoch 12/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8596
# Epoch 13/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3446 - accuracy: 0.8614
# Epoch 14/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.8596
# Epoch 15/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8607
# Epoch 16/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8614
# Epoch 17/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.8600
# Epoch 18/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3256 - accuracy: 0.8669
# Epoch 19/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3229 - accuracy: 0.8673
# Epoch 20/100
# 86/86 [==============================] - 0s 3ms/step - loss: 0.3181 - accuracy: 0.8680
# Epoch 21/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3152 - accuracy: 0.8709
# Epoch 22/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3102 - accuracy: 0.8698
# Epoch 23/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3068 - accuracy: 0.8727
# Epoch 24/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.3065 - accuracy: 0.8731
# Epoch 25/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2956 - accuracy: 0.8749
# Epoch 26/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2904 - accuracy: 0.8818
# Epoch 27/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2869 - accuracy: 0.8811
# Epoch 28/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2800 - accuracy: 0.8862
# Epoch 29/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8840
# Epoch 30/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2687 - accuracy: 0.8884
# Epoch 31/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2640 - accuracy: 0.8910
# Epoch 32/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2622 - accuracy: 0.8910
# Epoch 33/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2553 - accuracy: 0.8935
# Epoch 34/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.8968
# Epoch 35/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2468 - accuracy: 0.8957
# Epoch 36/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2385 - accuracy: 0.9030
# Epoch 37/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.9074
# Epoch 38/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.9019
# Epoch 39/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2277 - accuracy: 0.9066
# Epoch 40/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2191 - accuracy: 0.9063
# Epoch 41/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2187 - accuracy: 0.9121
# Epoch 42/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2147 - accuracy: 0.9132
# Epoch 43/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2039 - accuracy: 0.9183
# Epoch 44/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.2019 - accuracy: 0.9187
# Epoch 45/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1941 - accuracy: 0.9249
# Epoch 46/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1909 - accuracy: 0.9260
# Epoch 47/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1900 - accuracy: 0.9252
# Epoch 48/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1851 - accuracy: 0.9300
# Epoch 49/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1821 - accuracy: 0.9289
# Epoch 50/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1768 - accuracy: 0.9314
# Epoch 51/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1688 - accuracy: 0.9333
# Epoch 52/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1648 - accuracy: 0.9387
# Epoch 53/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1664 - accuracy: 0.9354
# Epoch 54/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1625 - accuracy: 0.9416
# Epoch 55/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1569 - accuracy: 0.9406
# Epoch 56/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1476 - accuracy: 0.9460
# Epoch 57/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1459 - accuracy: 0.9475
# Epoch 58/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1393 - accuracy: 0.9497
# Epoch 59/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1406 - accuracy: 0.9468
# Epoch 60/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1354 - accuracy: 0.9530
# Epoch 61/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1337 - accuracy: 0.9548
# Epoch 62/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 0.9544
# Epoch 63/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.9493
# Epoch 64/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1253 - accuracy: 0.9519
# Epoch 65/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1180 - accuracy: 0.9566
# Epoch 66/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9632
# Epoch 67/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1151 - accuracy: 0.9581
# Epoch 68/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.9654
# Epoch 69/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.9639
# Epoch 70/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9668
# Epoch 71/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0976 - accuracy: 0.9694
# Epoch 72/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1025 - accuracy: 0.9657
# Epoch 73/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9716
# Epoch 74/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0913 - accuracy: 0.9716
# Epoch 75/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0881 - accuracy: 0.9748
# Epoch 76/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0966 - accuracy: 0.9679
# Epoch 77/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.9661
# Epoch 78/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9686
# Epoch 79/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0845 - accuracy: 0.9730
# Epoch 80/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9726
# Epoch 81/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.9778
# Epoch 82/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9759
# Epoch 83/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9796
# Epoch 84/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0704 - accuracy: 0.9792
# Epoch 85/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9821
# Epoch 86/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0631 - accuracy: 0.9825
# Epoch 87/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.9726
# Epoch 88/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9778
# Epoch 89/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9818
# Epoch 90/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 0.9821
# Epoch 91/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9843
# Epoch 92/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 0.9891
# Epoch 93/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9880
# Epoch 94/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0619 - accuracy: 0.9792
# Epoch 95/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.9869
# Epoch 96/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 0.9854
# Epoch 97/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0798 - accuracy: 0.9741
# Epoch 98/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0769 - accuracy: 0.9748
# Epoch 99/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9840
# Epoch 100/100
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9883

# %%
#Evaluate the model using th test data
model_loss, model_accuracy=nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f'Loss: {model_loss}, Accuracy:{model_accuracy}')
# Out:
# 29/29 - 1s - loss: 1.1951 - accuracy: 0.8000 - 1s/epoch - 47ms/step
# Loss: 1.1951147317886353, Accuracy:0.800000011920929

# %%
y_pred=nn_model.predict(X_test_scaled)
y_pred=np.argmax(y_pred, axis=1)
# Out:
# 29/29 [==============================] - 0s 1ms/step

# %%
#Display the confusion matrix
cm=confusion_matrix(y_test, y_pred)
cm_df=pd.DataFrame(cm, index=['Actual 0','Actual 1'], columns=['Predicted 0', 'Predicted 1'])
cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0          776            0
# Actual 1          139            0

# %%
#Print the  classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       776
#            1       0.00      0.00      0.00       139
#
#     accuracy                           0.85       915
#    macro avg       0.42      0.50      0.46       915
# weighted avg       0.72      0.85      0.78       915
